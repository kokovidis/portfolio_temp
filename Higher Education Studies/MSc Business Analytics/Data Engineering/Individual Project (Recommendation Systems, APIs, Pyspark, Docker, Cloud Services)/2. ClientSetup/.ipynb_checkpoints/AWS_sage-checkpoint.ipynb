# %%
"""
The following code uses the 100k movie lens example to make inference against an endpoint deployed on Sakemaker
to determine if a movie is suitable for a user in the dataset.
This example uses two of the users in test set as an example to determine a score for the movie user combination
"""

import boto3, csv, json
import numpy as np
from scipy.sparse import lil_matrix

nbUsers = 943
nbMovies = 1682

moviesByUser = {}
for userId in range(nbUsers):
    moviesByUser[str(userId)] = []

def loadDataset(filename, lines, columns):
    # Features are one-hot encoded in a sparse matrix
    X = lil_matrix((lines, columns)).astype('float32')
    # Labels are stored in a vector
    Y = []
    line = 0
    with open(filename, 'r') as f:
        samples = csv.reader(f, delimiter='\t')
        for userId, movieId, rating, timestamp in samples:
            X[line, int(userId) - 1] = 1
            X[line, int(nbUsers) + int(movieId) - 1] = 1
            if int(rating) >= 4:
                Y.append(1)
            else:
                Y.append(0)
            line = line + 1

    Y = np.array(Y).astype('float32')
    return X, Y

# %%
import pandas as pd
load = pd.read_csv('/project/DataCollection/ratings.csv')
#nbMovies= load.movieId.nunique()
#nbUsers=1

nbUsers = 943
nbMovies = 1682

nbFeatures = nbUsers + nbMovies
load = load.loc[load.userId==11]

nbRatings = load.shape[0]
load.to_csv('temp.pred', sep='\t', header=False, index=False)

# %%
X_test, Y_test = loadDataset('temp.pred', nbRatings , nbFeatures)

data = X_test.toarray()

# this code serialises the data for use by the sagemaker API, in this case is expands the sparse matrix to a dense version
# see https://docs.aws.amazon.com/sagemaker/latest/dg/cdf-inference.html for more examples of dense ans spare formats
def fm_serializer(data):
    js = {'instances': []}
    for row in data:
        js['instances'].append({'features': row.tolist()})
    # print js
    return json.dumps(js)


payload = fm_serializer(data)

runtime_client = boto3.client('sagemaker-runtime', region_name='eu-west-2', aws_access_key_id='AKIA4LVLLZ6RVW3YN23V',
                              aws_secret_access_key='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')

# the endpoint traing on the 100k dataset and deployed to AWS
endpoint_name = 'factorization-machines-2020-03-14-18-20-08-738'
response = runtime_client.invoke_endpoint(EndpointName=endpoint_name,
                                          ContentType='application/json',
                                          Accept='application/json',
                                          Body=payload)

# the scoring returned for the datapoints for the user and movie
#print(response)
#print(response['Body'].read())

# %%
text = response['Body'].read().decode("utf-8")

# %%
import json

d = json.loads(text)
d['predictions']
# Out:
# [{'score': 0.4113192558288574, 'predicted_label': 0.0},
#  {'score': 0.5253480076789856, 'predicted_label': 1.0},
#  {'score': 0.4893607199192047, 'predicted_label': 0.0},
#  {'score': 0.4042651951313019, 'predicted_label': 0.0},
#  {'score': 0.5581875443458557, 'predicted_label': 1.0},
#  {'score': 0.45601779222488403, 'predicted_label': 0.0},
#  {'score': 0.3240577280521393, 'predicted_label': 0.0},
#  {'score': 0.15418727695941925, 'predicted_label': 0.0},
#  {'score': 0.24585725367069244, 'predicted_label': 0.0},
#  {'score': 0.23056110739707947, 'predicted_label': 0.0},
#  {'score': 0.4726409912109375, 'predicted_label': 0.0},
#  {'score': 0.7106837630271912, 'predicted_label': 1.0},
#  {'score': 0.498005747795105, 'predicted_label': 0.0},
#  {'score': 0.5535253286361694, 'predicted_label': 1.0},
#  {'score': 0.47566720843315125, 'predicted_label': 0.0},
#  {'score': 0.44765618443489075, 'predicted_label': 0.0},
#  {'score': 0.39757952094078064, 'predicted_label': 0.0},
#  {'score': 0.26378437876701355, 'predicted_label': 0.0},
#  {'score': 0.3356577455997467, 'predicted_label': 0.0},
#  {'score': 0.22619763016700745, 'predicted_label': 0.0},
#  {'score': 0.15501634776592255, 'predicted_label': 0.0},
#  {'score': 0.18908481299877167, 'predicted_label': 0.0},
#  {'score': 0.1686273217201233, 'predicted_label': 0.0},
#  {'score': 0.5025613307952881, 'predicted_label': 1.0},
#  {'score': 0.606513500213623, 'predicted_label': 1.0},
#  {'score': 0.3615361154079437, 'predicted_label': 0.0},
#  {'score': 0.6641566753387451, 'predicted_label': 1.0},
#  {'score': 0.5458634495735168, 'predicted_label': 1.0},
#  {'score': 0.6147419810295105, 'predicted_label': 1.0},
#  {'score': 0.583556056022644, 'predicted_label': 1.0},
#  {'score': 0.5176655054092407, 'predicted_label': 1.0},
#  {'score': 0.5880517959594727, 'predicted_label': 1.0},
#  {'score': 0.35990139842033386, 'predicted_label': 0.0},
#  {'score': 0.6456058025360107, 'predicted_label': 1.0},
#  {'score': 0.557965099811554, 'predicted_label': 1.0},
#  {'score': 0.40573182702064514, 'predicted_label': 0.0},
#  {'score': 0.14217537641525269, 'predicted_label': 0.0},
#  {'score': 0.42208749055862427, 'predicted_label': 0.0},
#  {'score': 0.5392102003097534, 'predicted_label': 1.0},
#  {'score': 0.6271361112594604, 'predicted_label': 1.0},
#  {'score': 0.6403815746307373, 'predicted_label': 1.0},
#  {'score': 0.3512677252292633, 'predicted_label': 0.0},
#  {'score': 0.2672116160392761, 'predicted_label': 0.0},
#  {'score': 0.42280516028404236, 'predicted_label': 0.0},
#  {'score': 0.642871618270874, 'predicted_label': 1.0},
#  {'score': 0.7001402974128723, 'predicted_label': 1.0},
#  {'score': 0.5747556686401367, 'predicted_label': 1.0},
#  {'score': 0.36647364497184753, 'predicted_label': 0.0},
#  {'score': 0.7283328771591187, 'predicted_label': 1.0},
#  {'score': 0.36589017510414124, 'predicted_label': 0.0},
#  {'score': 0.616319477558136, 'predicted_label': 1.0},
#  {'score': 0.5954778790473938, 'predicted_label': 1.0},
#  {'score': 0.21903946995735168, 'predicted_label': 0.0},
#  {'score': 0.4206368625164032, 'predicted_label': 0.0},
#  {'score': 0.2642967998981476, 'predicted_label': 0.0},
#  {'score': 0.4270755648612976, 'predicted_label': 0.0},
#  {'score': 0.20276792347431183, 'predicted_label': 0.0},
#  {'score': 0.44251883029937744, 'predicted_label': 0.0},
#  {'score': 0.48291274905204773, 'predicted_label': 0.0},
#  {'score': 0.6723440885543823, 'predicted_label': 1.0},
#  {'score': 0.32642388343811035, 'predicted_label': 0.0},
#  {'score': 0.4811001121997833, 'predicted_label': 0.0},
#  {'score': 0.43776935338974, 'predicted_label': 0.0},
#  {'score': 0.4594774544239044, 'predicted_label': 0.0},
#  {'score': 0.6005805730819702, 'predicted_label': 1.0},
#  {'score': 0.6957006454467773, 'predicted_label': 1.0},
#  {'score': 0.3837788999080658, 'predicted_label': 0.0},
#  {'score': 0.5622888207435608, 'predicted_label': 1.0},
#  {'score': 0.4958644211292267, 'predicted_label': 0.0},
#  {'score': 0.32010960578918457, 'predicted_label': 0.0},
#  {'score': 0.2797839343547821, 'predicted_label': 0.0},
#  {'score': 0.3048003911972046, 'predicted_label': 0.0},
#  {'score': 0.44831737875938416, 'predicted_label': 0.0},
#  {'score': 0.43283846974372864, 'predicted_label': 0.0},
#  {'score': 0.7437716722488403, 'predicted_label': 1.0},
#  {'score': 0.8011611104011536, 'predicted_label': 1.0},
#  {'score': 0.6481863260269165, 'predicted_label': 1.0},
#  {'score': 0.6930114030838013, 'predicted_label': 1.0},
#  {'score': 0.17803643643856049, 'predicted_label': 0.0},
#  {'score': 0.540751576423645, 'predicted_label': 1.0},
#  {'score': 0.4003562927246094, 'predicted_label': 0.0},
#  {'score': 0.5866925716400146, 'predicted_label': 1.0},
#  {'score': 0.5239855051040649, 'predicted_label': 1.0},
#  {'score': 0.2794417440891266, 'predicted_label': 0.0},
#  {'score': 0.6703229546546936, 'predicted_label': 1.0},
#  {'score': 0.5645729899406433, 'predicted_label': 1.0},
#  {'score': 0.5395018458366394, 'predicted_label': 1.0},
#  {'score': 0.21852998435497284, 'predicted_label': 0.0},
#  {'score': 0.5181463956832886, 'predicted_label': 1.0},
#  {'score': 0.6907326579093933, 'predicted_label': 1.0},
#  {'score': 0.318811297416687, 'predicted_label': 0.0},
#  {'score': 0.664211630821228, 'predicted_label': 1.0},
#  {'score': 0.20541468262672424, 'predicted_label': 0.0},
#  {'score': 0.2634149491786957, 'predicted_label': 0.0},
#  {'score': 0.5783094167709351, 'predicted_label': 1.0},
#  {'score': 0.591787576675415, 'predicted_label': 1.0},
#  {'score': 0.6926417946815491, 'predicted_label': 1.0},
#  {'score': 0.6667055487632751, 'predicted_label': 1.0},
#  {'score': 0.6138407588005066, 'predicted_label': 1.0},
#  {'score': 0.33559757471084595, 'predicted_label': 0.0},
#  {'score': 0.4811852276325226, 'predicted_label': 0.0},
#  {'score': 0.5563264489173889, 'predicted_label': 1.0},
#  {'score': 0.7035967707633972, 'predicted_label': 1.0},
#  {'score': 0.5009312033653259, 'predicted_label': 1.0},
#  {'score': 0.6149469614028931, 'predicted_label': 1.0},
#  {'score': 0.44151604175567627, 'predicted_label': 0.0},
#  {'score': 0.4346129894256592, 'predicted_label': 0.0},
#  {'score': 0.580592155456543, 'predicted_label': 1.0},
#  {'score': 0.3496161699295044, 'predicted_label': 0.0},
#  {'score': 0.43603840470314026, 'predicted_label': 0.0},
#  {'score': 0.8070881366729736, 'predicted_label': 1.0},
#  {'score': 0.47049954533576965, 'predicted_label': 0.0},
#  {'score': 0.24621707201004028, 'predicted_label': 0.0},
#  {'score': 0.22808393836021423, 'predicted_label': 0.0},
#  {'score': 0.6497299671173096, 'predicted_label': 1.0},
#  {'score': 0.5575350522994995, 'predicted_label': 1.0},
#  {'score': 0.5695399641990662, 'predicted_label': 1.0},
#  {'score': 0.624954879283905, 'predicted_label': 1.0},
#  {'score': 0.43402883410453796, 'predicted_label': 0.0},
#  {'score': 0.4735531210899353, 'predicted_label': 0.0},
#  {'score': 0.8400917053222656, 'predicted_label': 1.0},
#  {'score': 0.3146975636482239, 'predicted_label': 0.0},
#  {'score': 0.40294912457466125, 'predicted_label': 0.0},
#  {'score': 0.7733502388000488, 'predicted_label': 1.0},
#  {'score': 0.4921090602874756, 'predicted_label': 0.0},
#  {'score': 0.6137359738349915, 'predicted_label': 1.0},
#  {'score': 0.3709934949874878, 'predicted_label': 0.0},
#  {'score': 0.5426468253135681, 'predicted_label': 1.0},
#  {'score': 0.19982413947582245, 'predicted_label': 0.0},
#  {'score': 0.35610055923461914, 'predicted_label': 0.0},
#  {'score': 0.269264280796051, 'predicted_label': 0.0},
#  {'score': 0.30938440561294556, 'predicted_label': 0.0},
#  {'score': 0.4238353669643402, 'predicted_label': 0.0},
#  {'score': 0.43336114287376404, 'predicted_label': 0.0},
#  {'score': 0.16629037261009216, 'predicted_label': 0.0},
#  {'score': 0.4752950072288513, 'predicted_label': 0.0},
#  {'score': 0.39320334792137146, 'predicted_label': 0.0},
#  {'score': 0.5661231875419617, 'predicted_label': 1.0},
#  {'score': 0.4374888837337494, 'predicted_label': 0.0},
#  {'score': 0.48294755816459656, 'predicted_label': 0.0},
#  {'score': 0.5539582967758179, 'predicted_label': 1.0},
#  {'score': 0.6582942605018616, 'predicted_label': 1.0},
#  {'score': 0.6284197568893433, 'predicted_label': 1.0},
#  {'score': 0.5587815642356873, 'predicted_label': 1.0},
#  {'score': 0.6384179592132568, 'predicted_label': 1.0},
#  {'score': 0.3354026973247528, 'predicted_label': 0.0},
#  {'score': 0.5302551984786987, 'predicted_label': 1.0},
#  {'score': 0.5116313099861145, 'predicted_label': 1.0},
#  {'score': 0.49315476417541504, 'predicted_label': 0.0},
#  {'score': 0.253769189119339, 'predicted_label': 0.0},
#  {'score': 0.812350869178772, 'predicted_label': 1.0},
#  {'score': 0.28152191638946533, 'predicted_label': 0.0},
#  {'score': 0.6588783860206604, 'predicted_label': 1.0},
#  {'score': 0.3857654631137848, 'predicted_label': 0.0},
#  {'score': 0.2865302562713623, 'predicted_label': 0.0},
#  {'score': 0.6648584604263306, 'predicted_label': 1.0},
#  {'score': 0.6079147458076477, 'predicted_label': 1.0},
#  {'score': 0.4582686722278595, 'predicted_label': 0.0},
#  {'score': 0.5509341955184937, 'predicted_label': 1.0},
#  {'score': 0.4014008343219757, 'predicted_label': 0.0},
#  {'score': 0.8049460649490356, 'predicted_label': 1.0},
#  {'score': 0.6077156662940979, 'predicted_label': 1.0},
#  {'score': 0.64715576171875, 'predicted_label': 1.0},
#  {'score': 0.5285160541534424, 'predicted_label': 1.0},
#  {'score': 0.4218847453594208, 'predicted_label': 0.0},
#  {'score': 0.4544195830821991, 'predicted_label': 0.0},
#  {'score': 0.4869200587272644, 'predicted_label': 0.0},
#  {'score': 0.6233155131340027, 'predicted_label': 1.0},
#  {'score': 0.40851446986198425, 'predicted_label': 0.0},
#  {'score': 0.6674439311027527, 'predicted_label': 1.0},
#  {'score': 0.3984715938568115, 'predicted_label': 0.0},
#  {'score': 0.4130661189556122, 'predicted_label': 0.0},
#  {'score': 0.3620802164077759, 'predicted_label': 0.0},
#  {'score': 0.2968157231807709, 'predicted_label': 0.0},
#  {'score': 0.4772195816040039, 'predicted_label': 0.0},
#  {'score': 0.424602746963501, 'predicted_label': 0.0},
#  {'score': 0.4073982238769531, 'predicted_label': 0.0},
#  {'score': 0.2731369137763977, 'predicted_label': 0.0},
#  {'score': 0.39622724056243896, 'predicted_label': 0.0},
#  {'score': 0.5945684313774109, 'predicted_label': 1.0},
#  {'score': 0.4483833312988281, 'predicted_label': 0.0}]

# %%
pd.DataFrame(d['predictions'])
# Out:
#         score  predicted_label
# 0    0.411319              0.0
# 1    0.525348              1.0
# 2    0.489361              0.0
# 3    0.404265              0.0
# 4    0.558188              1.0
# ..        ...              ...
# 176  0.407398              0.0
# 177  0.273137              0.0
# 178  0.396227              0.0
# 179  0.594568              1.0
# 180  0.448383              0.0
#
# [181 rows x 2 columns]
